# %% [markdown]
# # Data Center Guardian - MLOps Compute Plane
#
# This notebook orchestrates the cloud compute for the Backblaze predictive maintenance platform.
#
# ## Google Drive Authentication Instructions
# 1. When you run the second cell, a popup will appear asking for permission to access your Google Drive.
# 2. Click **Connect to Google Drive** and sign in with your Google account.
# 3. This mounts your drive at `/content/drive`. The ETL output and `survival_model.onnx` will be saved here so you do not lose them when the Colab instance shuts down.
#
# Make sure you select a **T4 GPU** runtime from `Runtime > Change runtime type` for maximum XGBoost `hist` acceleration.

# %%
# !pip install polars xgboost onnx onnxmltools onnxruntime

from google.colab import drive
drive.mount('/content/drive')

# !git clone https://github.com/bettercallok/data-center-gaurdian.git
# %cd data-center-gaurdian
# !pip install -r requirements.txt

# %%
# Run the ETL pipeline to extract Q4 2023 data
# !python src/etl/pipeline.py

# Run the XGBoost AFT training using GPU and export to ONNX
# !python src/ml/train_survival.py
